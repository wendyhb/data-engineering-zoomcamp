# %%
import pandas as pd
import warnings

# %%
pd.__version__
# Out:
# '2.2.0'

# %%
### QUESTION 3 Count records: 15612
warnings.filterwarnings("ignore")
df = pd.read_csv('green_tripdata_2019-09.csv')

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
df['lpep_pickup_datetime']
# Out:
# 0        2019-09-01 00:10:53
# 1        2019-09-01 00:31:22
# 2        2019-09-01 00:50:24
# 3        2019-09-01 00:27:06
# 4        2019-09-01 00:43:23
#                  ...
# 449058   2019-09-30 23:13:00
# 449059   2019-09-30 23:26:00
# 449060   2019-09-30 23:15:00
# 449061   2019-09-30 23:19:00
# 449062   2019-09-30 23:35:00
# Name: lpep_pickup_datetime, Length: 449063, dtype: datetime64[ns]

# %%
df_q3 = df[
    (df['lpep_pickup_datetime'].dt.date == pd.to_datetime('2019-09-18').date()) &
    (df['lpep_dropoff_datetime'].dt.date == pd.to_datetime('2019-09-18').date())
]

df_q3
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 217634       2.0  2019-09-18 09:12:39   2019-09-18 09:20:14
# 218133       2.0  2019-09-18 10:05:23   2019-09-18 10:12:42
# 218134       2.0  2019-09-18 10:53:43   2019-09-18 11:00:01
# 218254       2.0  2019-09-18 00:02:54   2019-09-18 00:08:54
# 218281       2.0  2019-09-18 00:03:40   2019-09-18 00:23:29
# ...          ...                  ...                   ...
# 423824       NaN  2019-09-18 23:10:00   2019-09-18 23:28:00
# 423825       NaN  2019-09-18 23:18:00   2019-09-18 23:59:00
# 423828       NaN  2019-09-18 23:00:00   2019-09-18 23:15:00
# 423830       NaN  2019-09-18 23:19:00   2019-09-18 23:34:00
# 423831       NaN  2019-09-18 23:04:00   2019-09-18 23:14:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 217634                  N         1.0            95           134
# 218133                  N         1.0            95           196
# ...

# %%
## QUESTION 4  Longest trip for each day (given 4 days)
df = pd.read_csv('green_tripdata_2019-09.csv')
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
# Out:
# C:\Users\cyn64\AppData\Local\Temp\ipykernel_7964\1586932325.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('green_tripdata_2019-09.csv')

# %%
dates_q4 = ['2019-09-16','2019-09-18','2019-09-21','2019-09-26']
df = df[
 df['lpep_pickup_datetime'].dt.date.isin(pd.to_datetime(dates_q4).date)
]

# %%
max_perday = df.groupby(df['lpep_pickup_datetime'].dt.date)['trip_distance'].max()

# %%
max_perday
# Out:
# lpep_pickup_datetime
# 2019-09-16    114.30
# 2019-09-18     70.28
# 2019-09-21    135.53
# 2019-09-26    341.64
# Name: trip_distance, dtype: float64

# %%
## QUESTION 5
df = pd.read_csv('green_tripdata_2019-09.csv')
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df_q5 = df[
    (df['lpep_pickup_datetime'].dt.date ==  pd.to_datetime('2019-09-18').date())]

# %%
df_zone = pd.read_csv('taxi_zone_lookup.csv')
df = pd.merge(df, df_zone, left_on = 'PULocationID', right_on = 'LocationID', how = 'inner')

# %%
q5 = df.groupby(df['Borough'])['total_amount'].sum()
q5
# Out:
# Borough
# Bronx             818158.06
# Brooklyn         2619378.54
# EWR                  719.70
# Manhattan        2427880.92
# Queens           2460386.17
# Staten Island      11248.31
# Unknown            25852.58
# Name: total_amount, dtype: float64

# %%
## QUESTION 6
df = pd.read_csv('green_tripdata_2019-09.csv')
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

df_zone = pd.read_csv('taxi_zone_lookup.csv')
df = pd.merge(df, df_zone, left_on = 'PULocationID', right_on = 'LocationID', how = 'inner')

# %%
df = df[
    (df['Zone'] == 'Astoria')
]

# %%
df = pd.merge(
    df, df_zone, 
    left_on = 'DOLocationID', right_on = 'LocationID', 
    how = 'inner', suffixes=('_PU', '_DO')
)

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0           2.0  2019-09-01 00:55:37   2019-09-01 01:17:02                  N
# 1           1.0  2019-09-01 00:35:43   2019-09-01 00:47:21                  N
# 2           2.0  2019-09-01 00:58:19   2019-09-01 01:07:00                  N
# 3           2.0  2019-09-01 00:15:10   2019-09-01 00:18:22                  N
# 4           2.0  2019-09-01 00:21:37   2019-09-01 00:33:31                  N
# ...         ...                  ...                   ...                ...
# 18274       NaN  2019-09-30 14:26:00   2019-09-30 15:03:00                NaN
# 18275       NaN  2019-09-30 15:00:00   2019-09-30 15:29:00                NaN
# 18276       NaN  2019-09-30 15:22:00   2019-09-30 15:51:00                NaN
# 18277       NaN  2019-09-30 20:17:00   2019-09-30 20:56:00                NaN
# 18278       NaN  2019-09-30 21:30:00   2019-09-30 21:51:00                NaN
#
# ...

# %%
df.sort_values(by='tip_amount')[['tip_amount', 'Zone_DO']]
# ax_tip_amount_by_zone.idxmax()
# Out:
#        tip_amount         Zone_DO
# 0            0.00  Central Harlem
# 11055        0.00       Sunnyside
# 11056        0.00         Astoria
# 11059        0.00     Old Astoria
# 11060        0.00         Astoria
# ...           ...             ...
# 8081        20.00         Astoria
# 1015        25.00              NV
# 14507       28.00        Kips Bay
# 8215        30.00        Woodside
# 4277        62.31     JFK Airport
#
# [18279 rows x 2 columns]
